# %%
def am9():
    print("Good morning team")
am9()
# Out:
# Good morning team

# %%
def greet():
    print('Hello')
    print('Team')
    print('Good morning')
greet()
# Out:
# Hello
# Team
# Good morning

# %%
def greet():
    print('Hello')
    print('Team')
    print('Good morning')
greet()
greet()
greet()
# Out:
# Hello
# Team
# Good morning
# Hello
# Team
# Good morning
# Hello
# Team
# Good morning

# %%
def sum(x,y):
    c=x+y;
    print(c)
sum(2,3)
# Out:
# 5

# %%
def sum(x,y):
    c=x+y;
    print(c)
sum(2,3,4,5,6,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2     c=x+y;
#       3     print(c)
# ----> 4 sum(2,3,4,5,6,7)
#
# TypeError: sum() takes 2 positional arguments but 6 were given

# %%
def add(a,b,c,d):
    z=a+b+c+d;
    print(z)
add(2,3,4,5)
# Out:
# 14

# %%
def add(x,y):
    z=x+y;
    print(z)
add(2,3)
def greet():
   print("Hello World")
greet()
# Out:
# 5
# Hello World

# %%
def add(x,y):
    z=x+y;
    print(z)
add(8,3)
def greet():
   print("Hello World")
greet()
def sub(x,y):
    d=x-y;
    print(d)
sub(8,3)
# Out:
# 11
# Hello World
# 5

# %%
def add_sub(a,b):
    x=a+b;
    y=a-b;
    return x,y
add_sub(9,7)
# Out:
# (16, 2)

# %%
def add_sub(a,b):
    x=a+b;
    y=a-b;
    return x,y
result=add_sub(9,7)
print (result)
# Out:
# (16, 2)

# %%
#FORMAL ARGUMENT & ACTUAL ARGUMENT

# %%
def person(name,age):
    print(name)
    print(age)
person('nit',23,24)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2     print(name)
#       3     print(age)
# ----> 4 person('nit',23,24)
#
# TypeError: person() takes 2 positional arguments but 3 were given

# %%
def person(name,age):
    print(name)
    print(age)
    
person('nit',23)
# Out:
# nit
# 23

# %%
def person(name,age):
    print(name)
    print(age)
    
person(23,'nit')
# Out:
# 23
# nit

# %%
def person(name,age):
    print(name)
    print(age+1)
    
person(23,'nit')
# Out:
# 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2     print(name)
#       3     print(age+1)
# ----> 5 person(23,'nit')
#
# Cell In[10], line 3, in person(name, age)
#       1 def person(name,age):
#       2     print(name)
# ----> 3     print(age+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def person(name,age1):
    print(name)
    print(age1+1)
    
person(age1=23, name='nit')
# Out:
# nit
# 24

# %%
def person(name,age1):
    print(name)
    print(age1+1)
    
person('nit',23)
# Out:
# nit
# 24

# %%
#Loacl vs global

# %%
def sum(a,b):
    c=a+b;
    return c
sum(6,8)
# Out:
# 14

# %%
def sum(a,b):
    c=a+b;
    return c
sum(6,8,9,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2     c=a+b;
#       3     return c
# ----> 4 sum(6,8,9,20,30)
#
# TypeError: sum() takes 2 positional arguments but 5 were given

# %%
def sum(a,*b):
    x=a+b;
    return x
sum(10,20,30,40,50,60,70,80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2     x=a+b;
#       3     return x
# ----> 4 sum(10,20,30,40,50,60,70,80)
#
# Cell In[19], line 2, in sum(a, *b)
#       1 def sum(a,*b):
# ----> 2     x=a+b;
#       3     return x
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
def sum(a,*b):
   # x=a+b;
   # return x
    print(type(a))
    print(type(b))
          
sum(15,25,35,45,55,65,75)
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
def sum(a,*b):
    c=a;
    for i in b:
        c=c+i;
        print (c)
sum(12,13,14,15,16,17,18)
# Out:
# 25
# 39
# 54
# 70
# 87
# 105

# %%
def sum(a,*b):
    c=a;
    for i in b:
        c=c+i;
    print (c)
sum(12,13,14,15,16,17,18)
# Out:
# 105

# %%
Positinal arguement and Keyword arguement

# %%
def person(name, *data):
    print(name)
    print(data)

person('ALEX', 36, 'JOHN', 987767)
# Out:
# ALEX
# (36, 'JOHN', 987767)

# %%
def person(name,**data):
    print('name')
    print(data)

person('ALEX', age = 36, home_place ='southcity', mob =987767, edu = 'phd')
# Out:
# name
# {'age': 36, 'home_place': 'southcity', 'mob': 987767, 'edu': 'phd'}

# %%
#global varaibe vs local variable

# %%
a = 10   

def something():
    b = 15 
    print('in function',b)    
    print('out function',a)

# %%
a = 10   

def something():
    b = 15 
    print('in function',b)    
print('out function',a)
# Out:
# out function 10

# %%
a = 10   

def something():
    b = 15 
    print('in function',a)    
print('out function',a)
# Out:
# out function 10

# %%
a = 10   

def something():
    b = 15 
print('in function',a)    
print('out function',a)
# Out:
# in function 10
# out function 10

# %%
a = 10  

def something():
    b = 15
    print('in function',b)
    
something()
    
print('out function',a)
# Out:
# in function 15
# out function 10

# %%
a = 10  

def something():
    global a 
    b = 15
    print('in function',b)
    print('gloabl variable', a)
something()
print('out function',a)
# Out:
# in function 15
# gloabl variable 10
# out function 10

# %%
x = 10  

def update_x():
    global x  
    x += 5  
   
update_x()
print(x)
# Out:
# 15

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
def count(lst):
    

lst = [1,2,3,4,8,9,10]
lst
# Out:
#   Cell In[39], line 4
#     lst = [1,2,3,4,8,9,10]
#     ^
# IndentationError: expected an indented block after function definition on line 1
