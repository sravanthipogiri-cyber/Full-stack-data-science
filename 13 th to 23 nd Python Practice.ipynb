# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # Python variable=Identifier=Object

# %%
q=0
Q
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 q=0
# ----> 2 Q
#
# NameError: name 'Q' is not defined

# %%
k=20
k=30
k=40
k
# Out:
# 40

# %%
x=4,y=9,z=5
print(x),print(a),print(z)
# Out:
#   Cell In[5], line 1
#     x=4,y=9,z=5
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
x=4
y=9
z=5
print(x),print(z),print(a)
# Out:
# 4
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 y=9
#       3 z=5
# ----> 4 print(x),print(z),print(a)
#
# NameError: name 'a' is not defined

# %%
v=2
v=1+2k
v=2309.45
# Out:
#   Cell In[11], line 2
#     v=1+2k
#         ^
# SyntaxError: invalid decimal literal

# %%
# Incorrect - causes "invalid decimal literal" error
# 2x = 10
# 5y = 20

# Correct variable naming
x2 = 10       # Numbers can appear after the first character
y_5 = 20      # Underscores are allowed
variable1 = 30
_test = 40    # Starting with underscore is allowed
camelCase = 50
snake_case = 60

# If you need to represent a coefficient like "2x", use multiplication
x = 5
result = 2 * x  # This is how to represent "2x" in Python

print(x2, y_5, variable1)
# Out:
# 10 20 30

# %%
g9=90
g_3=80
Practice=70
print(g9,g_3,Practice)
# Out:
# 90 80 70

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # Syntax(variable=value)
# # reserved key words-`with`, `if`, `for`, `while`, etc

# %%
with=58
with
# Out:
#   Cell In[20], line 1
#     with=58
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Type casing
# convert one data type to other data type
# All other data types to integers

# %%
int(1.67)
# Out:
# 1

# %%
int(True)
int(False)
int(False)
int('37')
# Out:
# 37

# %%
int(19+23kl)
# Out:
#   Cell In[23], line 1
#     int(19+23kl)
#             ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # In Type casting we cannot convert complex values,String to int or cannot define two arguements at a time

# %%
All other data types to float
float(456)
float('Sravanthi')
float('345.6338567836587')
float(true)
float(False)
float(True,False)
# Out:
#   Cell In[21], line 1
#     All other data types to float
#         ^
# SyntaxError: invalid syntax

# %%
float(456)
# Out:
# 456.0

# %%
float('Sravanthi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 float('Sravanthi')
#
# ValueError: could not convert string to float: 'Sravanthi'

# %%
float('345.6338567836587')
# Out:
# 345.6338567836587

# %%
float(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 float(true)
#
# NameError: name 'true' is not defined

# %%
float(False)
# Out:
# 0.0

# %%
float(True,False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 float(True,False)
#
# TypeError: float expected at most 1 argument, got 2

# %% [markdown]
# # All datatypes to String

# %%
str(45)
# Out:
# '45'

# %%
str(435.0997877)
# Out:
# '435.0997877'

# %%
str('223242442')
# Out:
# '223242442'

# %%
str(True)
# Out:
# 'True'

# %%
str(animal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 str(animal)
#
# NameError: name 'animal' is not defined

# %% [markdown]
# # all data type to boolean

# %%
bool(-12)
# Out:
# True

# %%
bool('Saha')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(3+5h)
# Out:
#   Cell In[39], line 1
#     bool(3+5h)
#            ^
# SyntaxError: invalid decimal literal

# %%
bool(1+2j)
# Out:
# True

# %%
h = 2
result = 3 + 5 * h 
h
# Out:
# 2

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(23+4rg)
# Out:
#   Cell In[46], line 1
#     complex(23+4rg)
#                ^
# SyntaxError: invalid decimal literal

# %%
complex('20')
# Out:
# (20+0j)

# %%
complex('Sravanthi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 complex('Sravanthi')
#
# ValueError: complex() arg is a malformed string

# %% [markdown]
# # Data Type- User can define only one value to variable
# # Datastructure-User can define multiple values to variable

# %%
F=1e*0
# Out:
#   Cell In[50], line 1
#     F=1e*0
#       ^
# SyntaxError: invalid decimal literal

# %%
f=1e0
f
# Out:
# 1.0

# %%
f=2e5
f
# Out:
# 200000.0

# %%
h=3.897e7
h
# Out:
# 38970000.0

# %%
id(h)
# Out:
# 2615557692976

# %% [markdown]
# # Address of the memory location is id

# %%
p=30
g=45
y=45
id(g)
# Out:
# 140715388418344

# %%
print(id(g))
# Out:
# 140715388418344

# %%
g= 'Sravanthi'
g
# Out:
# 'Sravanthi'

# %%
print(g[-2])
print(g[-5])
print(g[-5])
print(g[2])
print(g[6])
# Out:
# h
# a
# a
# a
# t

# %%
g[-6:-4]
# Out:
# 'va'

# %%
g[1:6]
# Out:
# 'ravan'

# %%
g[0:3:6]
# Out:
# 'S'

# %%
g[0:8:2]
# Out:
# 'Saat'

# %%
g[::1]
# Out:
# 'Sravanthi'

# %%
g[::3]
# Out:
# 'Svt'

# %% [markdown]
# # 18/10/25 OPERATORS
#
# ARITHMATIC OPERATORS

# %%
a=10
b=20
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 10

# %%
a**b
# Out:
# 100000000000000000000

# %% [markdown]
# # Assignment OPERATORS

# %%
x=8
x
# Out:
# 8

# %%
x+=3
x
# Out:
# 11

# %%
x-=2
x
# Out:
# 9

# %%
x*=4
x
# Out:
# 36

# %%
x/=4
x
# Out:
# 9.0

# %%
x%=3
x
# Out:
# 0.0

# %%
x=9
x
# Out:
# 9

# %%
x=80
x//=4
x
# Out:
# 20.0

# %%
x=4
x**=3
x
# Out:
# 64

# %%
x=8
x&=5
x
# Out:
# 0

# %%
x=5
x |=8
x
# Out:
# 13

# %% [markdown]
# # Relational Operators

# %%
num1=200
num2=300
num1>num2
# Out:
# False

# %%
num1<num2
# Out:
# True

# %%
num1>=num2
# Out:
# False

# %%
num1<=num2
# Out:
# True

# %%
num1==num2
# Out:
# False

# %%
num1!=num2
# Out:
# True

# %%
num1=300

# %%
num1==num2
# Out:
# True

# %%
num1!=num2
# Out:
# False

# %% [markdown]
# # Logical operators

# %%
m=80
print(m>20 and m<100)
# Out:
# True

# %%
print(not(m>95 and m<20))
# Out:
# True

# %% [markdown]
# # unary operator

# %%
x=10
y=-x
y
# Out:
# -10

# %%
x=True
y!=x
y
# Out:
# -10

# %%
x=True
y= not x
y
# Out:
# False

# %% [markdown]
# # Bitwisw operators

# %%
~90
# Out:
# -91

# %%
print(~99)
# Out:
# -100

# %%
bin(101)
# Out:
# '0b1100101'

# %%
bin(73)
# Out:
# '0b1001001'

# %%
binary_num="1010"
int(binary_num,2)
# Out:
# 10

# %%
binary_num="01101100101101001"
int(binary_num,2)
# Out:
# 55657

# %%
binary_num="01101100101101001"
int(binary_num,3)
# Out:
# 19848025

# %%
oct(5)
# Out:
# '0o5'

# %%
int(0o31)
# Out:
# 25

# %%
oct(250)
# Out:
# '0o372'

# %%
oct(8)
# Out:
# '0o10'

# %%
oct(20)
# Out:
# '0o24'

# %%
hex(35)
# Out:
# '0x23'

# %%
hex(12.67)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hex(12.67)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
oct(12.67)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 oct(12.67)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
hex(234)
# Out:
# '0xea'

# %%
print(30 & 40)
# Out:
# 8

# %%
10 & 20
# Out:
# 0

# %%
print(24.5 and 65.5)
# Out:
# 65.5

# %%
print(24.5 & 65.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(24.5 & 65.5)
#
# TypeError: unsupported operand type(s) for &: 'float' and 'float'

# %%
68.2 & 92.3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 68.2 & 92.3
#
# TypeError: unsupported operand type(s) for &: 'float' and 'float'

# %%
68 & 95
# Out:
# 68

# %%
100 & 125
# Out:
# 100

# %%
20 & 80
# Out:
# 16

# %%
bin(67)
bin(89)
67 | 89
# Out:
# 91

# %%
print(bin(67))
print(bin(89))
67 ^ 89
# Out:
# 0b1000011
# 0b1011001
# 26

# %%
89 ^ 56
# Out:
# 97

# %%
900<<1
# Out:
# 1800

# %%
bin(900)
# Out:
# '0b1110000100'

# %%
int(0b1110000100)
# Out:
# 900

# %%
6<<2
# Out:
# 24

# %%
6<<1
# Out:
# 12

# %%
1>>8
# Out:
# 0

# %%
9>>90
# Out:
# 0

# %%
9>>
# Out:
#   Cell In[30], line 1
#     9>>
#        ^
# SyntaxError: invalid syntax

# %%
1>>9
# Out:
# 0

# %% [markdown]
# # Data strutures

# %% [markdown]
# # List

# %%
List1=[]
print (List1)
print (type(List1))
# Out:
# []
# <class 'list'>

# %%
List1=[10,100.2,True,'2v+7','Sravanthi','{"AI1","AI2","AI3"}']
len(List1)
# Out:
# 6

# %% [markdown]
# # Assistant
# The error occurs because you're trying to create a list using square brackets but with commas between the elements without proper syntax. In Python, a list is defined using square brackets with commas separating the elements, but you've written it as if you're trying to access an index with a tuple.
#
# Would you like me to provide the corrected code?

# %%
# Corrected code - use square brackets with commas to properly define a list
List1 = [10, 100.2, True, '2v+7', 'Sravanthi', '{"AI1","AI2","AI3"}']
len(List1)
# Out:
# 6

# %%
print(List1[0])
# Out:
# 10

# %%
list2 = ['a', 'e', 'i', 'o', 'u']
list2
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
list2[0:3]
# Out:
# ['a', 'e', 'i']

# %%
list2[2:5]
# Out:
# ['i', 'o', 'u']

# %%
list2[:3]
# Out:
# ['a', 'e', 'i']

# %%
list2[-2:]
# Out:
# ['o', 'u']

# %%
list2.append('z')
list2
# Out:
# ['a', 'e', 'i', 'o', 'u', 'z', 'z', 'z', 'z']

# %%
list2.insert(5,'o')
list2
# Out:
# ['a', 'e', 'i', 'o', 'u', 'o', 'z', 'z', 'z', 'z']

# %%
list2.remove('z')
list2
# Out:
# ['a', 'e', 'i', 'o', 'u', 'o', 'z']

# %%
list2.pop(5) 
list2
# Out:
# ['a', 'e', 'i', 'o', 'u', 'z']

# %%
del list2[5] 
list2
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
list2[0] = 'u'
list2[1] = 'o'
list2[2] = 'i'
list2[3] = 'e'
list2[4] = 'a'
list2
# Out:
# ['u', 'o', 'i', 'e', 'a']

# %% [markdown]
# # Assistant
# The error occurs because you're trying to assign variables `u`, `o`, `i`, `e`, and `a` to elements of `list2`, but these variables haven't been defined. When assigning string values to a list, you need to enclose them in quotes to indicate they are strings, not variable names.
#
# Would you like me to provide the corrected code?

# %%
list2.clear()
list2
# Out:
# []

# %%
list2 = ['a', 'e', 'i', 'o', 'u']
list2
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
id(list2)
# Out:
# 1973922971776

# %%
id(list)
# Out:
# 140715178845344

# %%
List1[0]='g'
List1
# Out:
# ['g', 100.2, True, '2v+7', 'Sravanthi', '{"AI1","AI2","AI3"}']

# %%
list3=List1+list2
list3
# Out:
# ['g',
#  100.2,
#  True,
#  '2v+7',
#  'Sravanthi',
#  '{"AI1","AI2","AI3"}',
#  'a',
#  'e',
#  'i',
#  'o',
#  'u']

# %%
list2.extend(List1)
list2
# Out:
# ['a',
#  'e',
#  'i',
#  'o',
#  'u',
#  'g',
#  100.2,
#  True,
#  '2v+7',
#  'Sravanthi',
#  '{"AI1","AI2","AI3"}',
#  'g',
#  100.2,
#  True,
#  '2v+7',
#  'Sravanthi',
#  '{"AI1","AI2","AI3"}']

# %%
'Sravanthi'in list3
# Out:
# True

# %%
'Sravanthi'in List1
# Out:
# True

# %%
if 'Vowels'in List1:
    print ('Happy')
else:
    print ('sad')
# Out:
# sad

# %%
list2.reverse() 
list2
# Out:
# ['{"AI1","AI2","AI3"}',
#  'Sravanthi',
#  '2v+7',
#  True,
#  100.2,
#  'g',
#  '{"AI1","AI2","AI3"}',
#  'Sravanthi',
#  '2v+7',
#  True,
#  100.2,
#  'g',
#  'u',
#  'o',
#  'i',
#  'e',
#  'a']

# %%
list2  = list2[::-1] 
list2
# Out:
# ['a',
#  'e',
#  'i',
#  'o',
#  'u',
#  'g',
#  100.2,
#  True,
#  '2v+7',
#  'Sravanthi',
#  '{"AI1","AI2","AI3"}',
#  'g',
#  100.2,
#  True,
#  '2v+7',
#  'Sravanthi',
#  '{"AI1","AI2","AI3"}']

# %%
list2 = ['a', 'e', 'i', 'o', 'u']
list2.sort()
list2
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
list2 = ['a', 'e', 'i', 'o', 'u']
list2.sort(reverse=True)
list2
# Out:
# ['u', 'o', 'i', 'e', 'a']

# %%
list4 = [8, 6, 3, 2, 1, 9]
sorted(list4)
# Out:
# [1, 2, 3, 6, 8, 9]

# %%
for i in list4:
    print(i)
# Out:
# 8
# 6
# 3
# 2
# 1
# 9

# %%
for i in enumerate(list2):
    print(i)
# Out:
# (0, 'u')
# (1, 'o')
# (2, 'i')
# (3, 'e')
# (4, 'a')

# %%
list2.count('sravanthi')
# Out:
# 0

# %%
L1 = [1, 2, 3, 4, 0]

# %%
all(L1)
# Out:
# False

# %%
L2 = [1, 2, 3, 4, True]
all (L2)
# Out:
# True
