# %%
import streamlit as st

# %%
st.version
# Out:
# <module 'streamlit.version' from 'C:\\Users\\LENOVO\\anaconda3\\Lib\\site-packages\\streamlit\\version.py'>

# %%
st.title("My first Streamlit app created by sravanthi")
# Out:
# 2025-11-25 09:25:10.262 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 09:25:10.845
# ...
#   command:
#
#     streamlit run C:\Users\LENOVO\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-25 09:25:10.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.title("Welcome!This app calculates the square of a number")
# Out:
# 2025-11-25 09:25:10.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 09:25:10.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("select a number")
# Out:
# 2025-11-25 09:25:10.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 09:25:10.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
