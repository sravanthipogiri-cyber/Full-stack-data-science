# %%
import pandas as pd

# %%
ratings = pd.read_csv(r'D:\Kaggle\rating.csv')

# %%
ratings.shape
# Out:
# (20000263, 4)

# %% [markdown]
# #Kaggle task for data
#
# https://www.kaggle.com/code/harunshimanto/pandas-with-data-science-ai

# %%
import pandas as pd #import libraries

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16

# %%
nums=[12,18,2,26,15]
for num in nums:
     if num%5==0:
         print(num)
         break
else:
    print("Number not found")
# Out:
# 15

# %%
print(ratings.columns)
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
del ratings['rating']

# %%
# Check if 'timestamp' column exists before trying to delete it
if 'timestamp' in ratings.columns:
    del ratings['timestamp']
else:
    print("Column 'timestamp' does not exist in the DataFrame")
    
print(ratings.columns)
# Out:
# Column 'timestamp' does not exist in the DataFrame
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
ratings.head
# Out:
# <bound method NDFrame.head of           userId  movieId
# 0              1        2
# 1              1       29
# 2              1       32
# 3              1       47
# 4              1       50
# ...          ...      ...
# 20000258  138493    68954
# 20000259  138493    69526
# 20000260  138493    69644
# 20000261  138493    70286
# 20000262  138493    71619
#
# [20000263 rows x 2 columns]>

# %%
ratings.iloc[5]#iloc-Integer locations
# Out:
# userId       1
# movieId    112
# Name: 5, dtype: int64

# %%
row_0.index
# Out:
# Index(['A', 'B'], dtype='object')

# %% [markdown]
# # Assistant
# The error occurs because you're trying to use a variable `row_0` that hasn't been defined yet in your code.
#
# In Python, you need to define a variable before you can use it. The error message "NameError: name 'row_0' is not defined" indicates that Python doesn't recognize the variable `row_0` because it hasn't been created or assigned a value.
#
# Would you like me to provide the corrected code?

# %%
# First, define the row_0 variable
# For example, if row_0 should be a pandas Series or DataFrame row:
import pandas as pd

# Create a sample DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Define row_0 as the first row of the DataFrame
row_0 = df.iloc[0]

# Now you can access the index
row_0.index
# Out:
# Index(['A', 'B'], dtype='object')
