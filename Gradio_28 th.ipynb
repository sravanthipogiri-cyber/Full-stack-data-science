# %%
pip install gradio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr

def greet(name, intensity):
    return "Hello, " + name + "!" * int(intensity)

demo = gr.Interface(
    fn=greet,
    inputs=["text", "slider"],
    outputs=["text"],
    api_name="predict"
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from model import generate_image
import gardio as gr
with gr.Blocks()as demo()
gr.Markdown("#Your Fancy Image Generator")
with gr.Row(equal_height=True):
textbox=gr.Textbox(lines=1,show_label=False,
button=gr.Button("Generate",,variant="Primary")
image=gr.Image(height=250)
button.click(
    generate_image,
    inputs=textbox,
    outputs=image,
    demo.launch(share=True)
# Out:
#   Cell In[11], line 3
#     with gr.Blocks()as demo()
#                              ^
# SyntaxError: invalid syntax

# %%
from image_generator import generate_image
import gradio as gr  # Fixed typo in import (gardio -> gradio)

with gr.Blocks() as demo:  # Removed incorrect parentheses after Blocks()
    gr.Markdown("#Your Fancy Image Generator")
    with gr.Row(equal_height=True):
        textbox = gr.Textbox(lines=1, show_label=False)  # Fixed missing closing parenthesis
        button = gr.Button("Generate", variant="primary")  # Removed extra comma and fixed capitalization
        image = gr.Image(height=250)
    
    button.click(
        generate_image,
        inputs=textbox,
        outputs=image,
    )  # Added missing closing parenthesis
    
demo.launch(share=True)  # Fixed indentation - this should be outside the with block
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from image_generator import generate_image
#       2 import gradio as gr  # Fixed typo in import (gardio -> gradio)
#       4 with gr.Blocks() as demo:  # Removed incorrect parentheses after Blocks()
#
# ModuleNotFoundError: No module named 'image_generator'

# %%
# Option 1: Create the image_generator module if you need to implement it yourself
def generate_image(prompt):
    # Implement your image generation logic here
    # This is a placeholder function that returns a blank image
    import numpy as np
    return np.zeros((250, 250, 3))  # Returns a blank black image

# Option 2: Install and import an existing image generation library
# Uncomment the appropriate lines below:
# import torch
# from diffusers import StableDiffusionPipeline
# def generate_image(prompt):
#     model_id = "runwayml/stable-diffusion-v1-5"
#     pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
#     pipe = pipe.to("cuda")
#     image = pipe(prompt).images[0]
#     return image

import gradio as gr

with gr.Blocks() as demo:
    gr.Markdown("#Your Fancy Image Generator")
    with gr.Row(equal_height=True):
        textbox = gr.Textbox(lines=1, show_label=False)
        button = gr.Button("Generate", variant="primary")
        image = gr.Image(height=250)
    
    button.click(
        generate_image,
        inputs=textbox,
        outputs=image,
    )

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://5ad3f3e4534858d90e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5ad3f3e4534858d90e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
